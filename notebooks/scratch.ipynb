# %%
from subscript.defaults import ParamKeys

ParamKeys.dark_matter_profile_dmo_velocity_max
ParamKeys.dark_matter_profile_dmo_radius_velocity_max
# Out:
# 'darkMatterProfileDMORadiusVelocityMaximum'

# %%
from sidmcommon.nsphere_suite import summarize_nsphere_suite

dat = summarize_nsphere_suite('../data/NSphere/NSphere-galacticus-hr-cdm-test', 'summary.hdf5')
print(dat.keys())
# Out:
# Loading summary from cache: summary.hdf5
# Loading massbound for halo 10101 from cache
# Loading tidalf for halo 10101 from cache
# Loading time for halo 10101 from cache
# Loading massbound for halo 1130 from cache
# Loading tidalf for halo 1130 from cache
# Loading time for halo 1130 from cache
# Loading massbound for halo 11693 from cache
# Loading tidalf for halo 11693 from cache
# Loading time for halo 11693 from cache
# Loading massbound for halo 1232 from cache
# Loading tidalf for halo 1232 from cache
# Loading time for halo 1232 from cache
# Loading massbound for halo 12461 from cache
# Loading tidalf for halo 12461 from cache
# Loading time for halo 12461 from cache
# Loading massbound for halo 1330 from cache
# Loading tidalf for halo 1330 from cache
# Loading time for halo 1330 from cache
# Loading massbound for halo 1518 from cache
# Loading tidalf for halo 1518 from cache
# Loading time for halo 1518 from cache
# Loading massbound for halo 1607 from cache
# ...
